# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# special matplotlib argument for improved plots
from matplotlib import rcParams
rcParams['figure.dpi']= 100
sns.set_style("whitegrid")
sns.set_context("poster")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cae87ad16150> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import scipy.stats as stats
#       5 import matplotlib.pyplot as plt
#       6 import sklearn
#
# ModuleNotFoundError: No module named 'scipy'

# %%
pip install scipy
# Out:
# ...
#      |████████████████████████████████| 28.7 MB 599 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = df[np.isfinite(df['SCORE'])]

# %%
df.shape
##final amount of rows after removing data w/o SCORE
# Out:
# (379331, 26)

# %%
df.describe()
# Out:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  3.793310e+05  374012.000000  379331.000000  378933.000000
# mean   4.603927e+07   10679.256738      20.410214      40.157121
# std    4.413037e+06     596.537292      14.845434       4.791921
# min    3.007544e+07   10000.000000      -1.000000       0.000000
# 25%    4.138486e+07   10022.000000      11.000000      40.685882
# 50%    5.000500e+07   10468.000000      15.000000      40.732622
# 75%    5.005539e+07   11229.000000      26.000000      40.761957
# max    5.010062e+07   12345.000000     164.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  378933.000000    373614.000000     373614.000000  373614.000000
# mean      -72.904670       248.662759         20.008102   29015.023091
# std         8.699117       130.702788         15.778259   30780.673643
# min       -74.248434       101.000000          1.000000     100.000000
# ...

# %%
print(df.columns
    )
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA'],
#       dtype='object')

# %%
df.rename(columns={'CUISINE DESCRIPTION': 'CUISINE_DESCRIPTION'}, inplace=True)

# %%
pd.get_dummies(df,columns=['BORO', 'CUISINE_DESCRIPTION'], drop_first=True)
# Out:
#            CAMIS                                DBA BUILDING  \
# 0       50044393                       RYUJIN RAMEN      513
# 1       41488532                      THE COMMODORE      366
# 2       41387018                            HANCO'S      350
# 3       50004563            KANAN INDIAN RESTAURANT      452
# 4       50011004           BRAVO AFRICAN RESTAURANT     1473
# ...          ...                                ...      ...
# 396516  40367749                   LENNY'S CLAM BAR    16103
# 396517  50090861                          DRINK TEA     4722
# 396518  41064708          HOUSE OF PIZZA & CALZONES      132
# 396519  50075543                   FOO HING KITCHEN     2706
# 396520  41389468  MELANIE'S ROTI & GRILL RESTAURANT     1248
#
#                      STREET  ZIPCODE       PHONE INSPECTION DATE  \
# 0                  GRAND ST  11211.0  7187099888      10/04/2016
# 1       METROPOLITAN AVENUE  11211.0  7182187632      07/22/2017
# ...

# %%
df.BORO.value_counts()
# Out:
# Manhattan        148977
# Brooklyn          95992
# Queens            87014
# Bronx             34656
# Staten Island     12596
# 0                    96
# Name: BORO, dtype: int64

# %%
df.CUISINE_DESCRIPTION.value_counts()
# Out:
# American                                                            79837
# Chinese                                                             40907
# Café/Coffee/Tea                                                     18203
# Pizza                                                               16774
# Latin (Cuban, Dominican, Puerto Rican, South & Central American)    16584
#                                                                     ...
# Soups                                                                  56
# Czech                                                                  39
# Nuts/Confectionary                                                     33
# Chilean                                                                29
# Basque                                                                  5
# Name: CUISINE_DESCRIPTION, Length: 84, dtype: int64

# %%
df.shape
# Out:
# (379331, 26)

# %%
#splitting the dataset into training set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size)
